# %%
import numpy as np
import pandas as pd
from sklearn import datasets

# %%
df = pd.read_csv('iris.csv')

# %%
df.groupby('flower_class')

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.columns =['sepal_length', 'sepal_width','petal_length','petal_width','flower_class']

# %%
df.groupby('flower_class').describe()
# Out:
#                 sepal_length
#                        count   mean       std  min    25%  50%  75%  max
# flower_class
# Iris-setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8  \
# Iris-versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#                 sepal_width         ... petal_length      petal_width
#                       count   mean  ...          75%  max       count   mean
# flower_class                        ...
# Iris-setosa            50.0  3.418  ...        1.575  1.9        50.0  0.244  \
# Iris-versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# Iris-virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                       std  min  25%  50%  75%  max
# flower_class
# Iris-setosa      0.107210  0.1  0.2  0.2  0.3  0.6
# Iris-versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# ...

# %%
df.iloc[-1]
# Out:
# sepal_length            5.1
# sepal_width             3.5
# petal_length            1.4
# petal_width             0.2
# flower_class    Iris-setosa
# Name: 149, dtype: object

# %%
df.loc[len(df.index)]=[5.1,3.5,1.4,0.2,'Iris-setosa']

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
new_df = pd.DataFrame(df)
new_df['flower_class'] = df.flower_class.astype('category')

# %%
new_df['flower_class']= new_df['flower_class'].cat.codes

# %%
new_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  flower_class
# 0             4.9          3.0           1.4          0.2             0
# 1             4.7          3.2           1.3          0.2             0
# 2             4.6          3.1           1.5          0.2             0
# 3             5.0          3.6           1.4          0.2             0
# 4             5.4          3.9           1.7          0.4             0
# ..            ...          ...           ...          ...           ...
# 145           6.3          2.5           5.0          1.9             2
# 146           6.5          3.0           5.2          2.0             2
# 147           6.2          3.4           5.4          2.3             2
# 148           5.9          3.0           5.1          1.8             2
# 149           5.1          3.5           1.4          0.2             0
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
cat_setosa = df[df['flower_class'] == 'Iris-setosa']

# %%
cat_setosa = np.array(cat_setosa)

# %%
cat_setosa
# Out:
# array([[4.9, 3.0, 1.4, 0.2, 'Iris-setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'Iris-setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'Iris-setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'Iris-setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'Iris-setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'Iris-setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'Iris-setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'Iris-setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'Iris-setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'Iris-setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'Iris-setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'Iris-setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'Iris-setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'Iris-setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'Iris-setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'Iris-setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'Iris-setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'Iris-setosa'],
# ...

# %%
 cat_virginica= np.array(df[df['flower_class']=='Iris-virginica'])
cat_versicolor = np.array(df[df['flower_class']=='Iris-versicolor'])
plt.scatter(cat_setosa[:, 0], cat_setosa[:, 1], color='blue', label='setosa')
plt.scatter(cat_virginica[:, 0], cat_virginica[:, 1], color='yellow', label='virginica')
plt.scatter(cat_versicolor[:, 0], cat_versicolor[:, 1], color='red', label='versicolor')
plt.ylabel('sepal_width')
plt.xlabel('sepal_length')
plt.legend()
cat_v2.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
cat_versicolor= df[df['flower_class']=='Iris-versicolor']
cat_versicolor = np.array(cat_versicolor)

# %%
cat_versicolor
# Out:
# array([[7.0, 3.2, 4.7, 1.4, 'Iris-versicolor'],
#        [6.4, 3.2, 4.5, 1.5, 'Iris-versicolor'],
#        [6.9, 3.1, 4.9, 1.5, 'Iris-versicolor'],
#        [5.5, 2.3, 4.0, 1.3, 'Iris-versicolor'],
#        [6.5, 2.8, 4.6, 1.5, 'Iris-versicolor'],
#        [5.7, 2.8, 4.5, 1.3, 'Iris-versicolor'],
#        [6.3, 3.3, 4.7, 1.6, 'Iris-versicolor'],
#        [4.9, 2.4, 3.3, 1.0, 'Iris-versicolor'],
#        [6.6, 2.9, 4.6, 1.3, 'Iris-versicolor'],
#        [5.2, 2.7, 3.9, 1.4, 'Iris-versicolor'],
#        [5.0, 2.0, 3.5, 1.0, 'Iris-versicolor'],
#        [5.9, 3.0, 4.2, 1.5, 'Iris-versicolor'],
#        [6.0, 2.2, 4.0, 1.0, 'Iris-versicolor'],
#        [6.1, 2.9, 4.7, 1.4, 'Iris-versicolor'],
#        [5.6, 2.9, 3.6, 1.3, 'Iris-versicolor'],
#        [6.7, 3.1, 4.4, 1.4, 'Iris-versicolor'],
#        [5.6, 3.0, 4.5, 1.5, 'Iris-versicolor'],
#        [5.8, 2.7, 4.1, 1.0, 'Iris-versicolor'],
#        [6.2, 2.2, 4.5, 1.5, 'Iris-versicolor'],
#        [5.6, 2.5, 3.9, 1.1, 'Iris-versicolor'],
# ...

# %%
plt.scatter(cat_setosa[:, 0], cat_setosa[:, 1], color='blue', label='setosa')
plt.scatter(cat_virginica[:, 0], cat_virginica[:, 1], color='yellow', label='virginica')
plt.scatter(cat_v3[:, 0], cat_v3[:, 1], color='red', label='versicolor')
plt.ylabel('sepal_width')
plt.xlabel('sepal_length')
plt.legend()

# %% [markdown]
# plt.scatter(cat_setosa[:, 2], cat_setosa[:, 3], color='blue', label='setosa')
# plt.scatter(cat_virginica[:, 2], cat_virginica[:, 3], color='yellow', label='virginica')
# plt.scatter(cat_versicolor[:, 2], cat_versicolor[:, 3], color='red', label='versicolor')
# plt.ylabel('petal_width')
# plt.xlabel('petal_length')
# plt.legend()plt.scatter(cat_setosa[:, 0], cat_setosa[:, 1], color='blue', label='setosa')
# plt.scatter(cat_virginica[:, 0], cat_virginica[:, 1], color='yellow', label='virginica')
# plt.scatter(cat_versicolor[:, 0], cat_versicolor[:, 1], color='red', label='versicolor')
# plt.ylabel('sepal_width')
# plt.xlabel('sepal_length')
# plt.legend()

# %%
plt.scatter(cat_setosa[:, 0], cat_setosa[:, 2], color='blue', label='setosa')
plt.scatter(cat_virginica[:, 0], cat_virginica[:, 2], color='yellow', label='virginica')
plt.scatter(cat_versicolor[:, 0], cat_versicsepal_widtholor[:, 2], color='red', label='versicolor')
plt.ylabel('petal_lengthsepal_width')
plt.xlabel('sepal_lengCurriculum for Third Year of Computer Engineering (2019 Course), Savitribai Phule Pune University
http://collegeciplt.scatter(cat_setosa[:, 1], cat_setosa[:, 1], color='blue', label='setosa')
plt.scatter(cat_virginica[:, 0], cat_virginica[:, 1], color='yellow', label='virginica')
plt.scatter(cat_versicolor[:, 0], cat_versicolor[:, 1], color='red', label='versicolor')
plt.ylabel('sepal_width')
plt.xlabel('sepal_length')
plt.legend()rculars.unipune.ac.in/sites/documents/Syllabus2021/Forms/AllItems.aspx #79/99
3. Descriptive Statistics - Measures of Central Tendency and variability
Perform the following operations on any open source dataset (e.g., data.csv)
1. Provide summary statistics (mean, median, minimum, maximum, standard deviation) for
a dataset (age, income etc.) with numeric variables grouped by one of the qualitative
(categorical) variable. For example, if your categorical variable is age groups and
quantitative variable is income, then provide summary statistics of income grouped by
the age groups. Create a list that contains a numeric value for each response to the
categorical variable.
2. Write a Python program to display some basic statistical details like percentile, mean,
standarth')
plt.legend()

# %%
fig,axes = plt.subplots(1,4,figsize=(15,5))

# %%
import matplotlib1, .pyplot as plt

fig, axes = plt.subplots(1, 4, figsize=(15, 5))

# First subplot
axes[0].scatter(cat_setosa[:, 0], cat_setosa[:, 1], color='blue', label='setosa')
axes[0].scatter(cat_virginica[:, 0], cat_virginica[:, 1], color='yellow', label='virginica')
axes[0].scatter(cat_versicolor[:, 0], cat_versicolor[:, 1], color='red', label='versicolor')
axes[0].set_ylabel('sepal_width')
axes[0].set_xlabel('sepal_length')
axes[0].legend()

# Second subplot
axes[1].scatter(cat_setosa[:, 2], cat_setosa[:, 3], color='blue', label='setosa')
axes[1].scatter(c1, at_virginica[:, 2], cat_virginica[:, 3], color='yellow', label='virginica')
axes[1].scatter(cat_v3[:, 2], cat_v3[:, 3], color='red', label='versicolor')
axes[1].set_ylabel('petal_width')
axes[1].set_xlabel('petal_length')
axes[1].legend()

# Third subplot
axes[2].scatter(cat_setosa[:, 0], cat_setosa[:, 2], color='blue', label='setosa')
axes[2].scatter(cat_virginica[:, 0], cat_virginica[:, 2], color='yellow', label='virginica')
axes[2].scatter(cat_v3[:, 0], cat_v3[:, 2], color='red', label='versicolor')
axes[2].set_xlabel('sepal_length')
axes[2].set_ylabel('petal_length')  # Corrected label
axes[2].legend()

# Fourth subplot
axes[3].scatter(cat_setosa[:, 1], cat_setosa[:, 3], color='blue', label='setosa')
axes[3].scatter(cat_virginica[:, 1], cat_virginica[:, 3], color='yellow', label='virginica')
axes[3].scatter(cat_v3[:, 1], cat_v3[:, 3], color='red', label='versicolor')
axes[3].set_xlabel('sepal_width')
axes[3].set_ylabel('petal_width')
axes[3].legend()

# %% [markdown]
# Analysis : 1)Comparison of sepal width and sepal length -> With increase in sepal length, the sepal width of virginica and versicolor seems to be increasing, they seem to have positive correlation between the two.
# 2)setosa seems to be having the largest petal width, but is the smallest in all other attributes.
# 3)The Attributes for virginica and versicolor are all giving positive correlation.

# %%
setosa = df[df['flower_class'] == 'Iris-setosa'].drop('flower_class',axis=1)
virginica = df[df['flower_class'] == 'Iris-virginica'].drop('flower_class',axis=1)
versicolor = df[df['flower_class'] == 'Iris-versicolor'].drop('flower_class',axis=1)

setosa_filtered = pd.DataFrame()
virginica_filtered = pd.DataFrame()
versicolor_filtered filtered_setosa= pd.DataFrame()

for col in setosa.columns:filtered_setosa
    q1 = np.percentile(setosa[col], 25)
    q3 = np.percentile(setosa[col], 75)
    iqr = q3 - q1
    setosa_filtered = setosa[(setosa[col] >= (q1 - 1.5 * iqr)) & (setosa[col] <= (q3 + 1.5 * iqr))]

for col in virginica.columns:
    q1 = np.percentile(virginica[col], 25)
    q3 = np.percentifiltered_setosale(virginica[col], 75)
    iqr = q3 - q1
    virginica_filtered = virginica[(virginica[col] >= (q1 - 1.5 * iqr)) & (virginica[col] <= (q3 + 1.5 * iqr))]

for col in versicolor.columns:
    q1 = np.percentile(versicolor[col], 25)
    q3 = np.percentile(versicolor[col], 75)
    iqr = q3 - q1
    versicolor_filtered = versicolor[(versicolor[col] >= (q1 - 1.5 * iqr)) & (versicolor[col] <= (q3 + 1.5 * iqr))]

# %%
print(setosa.describe())
print(setosa_filtered.describe())filtered_setosa
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000
#        sepal_length  sepal_width  petal_length  petal_width
# count     48.000000    48.000000     48.000000    48.000000
# mean       5.004167     3.418750      1.456250     0.231250
# std        0.359644     0.388481      0.172474     0.087898
# min        4.300000     2.300000      1.000000     0.100000
# 25%        4.800000     3.100000      1.400000     0.200000
# 50%        5.000000     3.400000      1.500000     0.200000
# ...

# %%
fig2, axes2 = plt.subplots(1, 4, figsize=(15, 5))

setosa_filtered = np.array(setosa_filtered)
virginica_filtered = np.array(virginica_filtered)
versicolor_filtered = np.array(versicor='blue', label='setosa')
plt.scatter(cat_virginica[:, 0], cat_virginica[:, 1], color='yellow', label='virginica')
plt.scatter(cat_v3[:, 0], cat_v3[:, 1], color='red', label='vlor_filtered)

# First subplot
axes2[0].scatter(setosa_filtered[:, 0], setosa_filtered[:, 1], color='blue', label='setosa')
axes2[0].scatter(virginica_filtered[:, 0], virginica_filtered[:, 1], color='yellow', label='virginica')
axes2[0].scatter(filtered_setosaversicolor_filtered[:, 0], versicolor_filtered[:, 1], color='red', label='versicolor')
axes2[0].set_ylabel('filtered_setosasepal_width')
axes2[0].set_xlabel('sepal_length')
axes2[0].legend()
filtered_setosa
# Second subplot
axes2[1].scatter(setosa_filtered[:, 2], setosa_filtered[:, 3], color='blue', label='setosa')
axes2[1].scatter(virginica_filtered[:, 2], virginica_filtered[:, 3], color='yellow', label='virginica')
axes2[1].scatter(versicolor_filtered[:, 2], versicolor_filtered[:, 3], color='red', label='versicolor')
axes2[1].set_ylabel('petal_width')
axes2[1].set_xlabel('petal_length')
axes2[1].legend()

# Third subplotfiltered_setosa
axes2[2].scatter(setosa_filtered[:, 0],setosa_filtered[:, 2], color='blue', label='setosa')
axes2[2].scatter(virginica_filtered[:, 0], virginica_filtered[:, 2], color='yellow', label='virginica')
axes2[2].scatter(versicolor_filtered[:, 0], versicolor_filtered[:, 2], color='red', label='versicolor')
axes2[2].set_xlabel('sepal_length')
axes2[2].set_ylabel('petal_length')  # Corrected label
axes2[2].legend()

# Fourth subplot
axes2[3].scatter(setosa_filtered[:, 1], setosa_filtered[:, 3], color='blue', label='setosa')
axes2[3].scatter(virginica_filtered[:, 1], virginica_filtered[:, 3], color='yellow', label='virginica')
axes2[3].scatter(versicolor_filtered[:, 1], versicolor_filtered[:, 3], color='red', label='versicolor')
axes2[3].set_xlabel('sepal_width')
axes2[3].set_ylabel('petal_width')
axes2[3].legend()

# %%
setosa = df[df['flower_class'] == 'Iris-setosa']
q1 = np.percentile(setosa['sepal_length'],25)
q3 = np.percentile(setosa['sepal_length'],75)
iqr = q3-q1
print(setosa.describe())
bp = plt.boxplot(setosa['sepal_length'], whis=[q1-1.5*iqr,q3+1.5*iqr])
